# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_colwidth', 500)

# %%
df = pd.read_csv('doktorlar_ankara.csv')

# %%
df
# Out:
#                                 name  \
# 0                    Psk. Merve İnce
# 1                     Psk. Buse Kaya
# 2     Uzm. Kl. Psk. Bilge Canan Kurt
# 3                  Dyt. Selma Öztürk
# 4                Psk. Sümeyye Dikmen
# ...                              ...
# 9307  Ezgi Günör Fırat Muayenehanesi
# 9308        Alkan Dinç Muayenehanesi
# 9309    Osman Ertuğrul Muayenehanesi
# 9310    Yavuz Akçağlar Muayenehanesi
# 9311    Bahadır Dökmez Muayenehanesi
#
#                                                                                                         profile_image  \
# 0     //s3-eu-west-1.amazonaws.com/doktortakvimi.com/doctor/34a454/34a454c29bd7f4f63564ede6a84b9958_medium_square.jpg
# 1     //s3-eu-west-1.amazonaws.com/doktortakvimi.com/doctor/9061b0/9061b0a99161974c5c9927ea04b7db86_medium_square.jpg
# 2     //s3-eu-west-1.amazonaws.com/doktortakvimi.com/doctor/5f5512/5f5512737065a049b963a6bfa97e0cd5_medium_square.jpg
# ...

# %%
df.shape
# Out:
# (9312, 11)
